# %%
# %run app.py
# Out:
# 2024-11-24 14:20:35.785 | INFO     | __main__:<module>:292 - Running dash
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\venvs\semana5_DSA_MIAD_DashEquipo\Lib\site-packages\urllib3\connection.py:199, in HTTPConnection._new_conn(
#     self=<urllib3.connection.HTTPConnection object>
# )
#     198 try:
# --> 199     sock = connection.create_connection(
#         connection = <module 'urllib3.util.connection' from 'C:\\Users\\DELL\\AppData\\Local\\Programs\\Python\\Python312\\venvs\\semana5_DSA_MIAD_DashEquipo\\Lib\\site-packages\\urllib3\\util\\connection.py'>
#         (self._dns_host, self.port) = ('none', 8001)
# ...

# %%
'No'

# %%
map_si_no = {'No':0, 'Sí':1}
map_hombre_mujer = {'Mujer':0, 'Hombre':1}

# %%
'No'.map(map_si_no)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 'No'.map(map_si_no)
#
# AttributeError: 'str' object has no attribute 'map'

# %%
map_si_no['No']
# Out:
# 0

# %%
# !pip install loguru
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
